# %%
import json
import numpy as np

# %%
f = open('./results\generated_counterfactuals\OLID\counterfactuals_explain_wrt-predicted_next_token_strategy-confidence_direction-highest_first.json'.replace('\\', '/'))

# %%
# Using readlines()
lines = f.readlines()

jsons = []

# Strips the newline character
for line in lines[:10]:
    jsons.append(json.loads(line))

# %%
jsons[5]
# Out:
# {'id': 'test_83681',
#  'text': '. . . what the fuck did he do this time?',
#  'label': 1,
#  'original_label': 1,
#  'pred_label': 1,
#  'pred_proba': 0.8979050517082211,
#  'mask_frac': 0.3125,
#  'success': True,
#  'counterfactuals': [{'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#    'edited_output_text': 'not offensive :... what other thing could he do this time?',
#    'pred_proba': 0.2108921855688095,
#    'pred_class': 0,
#    'success': True,
#    'mask_frac': 0.3125,
#    'fluency': 3.33740456334272,
#    'sem_similarity': 0.6883240938186646,
#    'minimality': 0.5833333333333334,
#    'fluency_mice': 1.1602176990745543},
#   {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#    'edited_output_text': 'not offensive :... what of that did he do this time?',
#    'pred_proba': 0.21467173099517822,
#    'pred_class': 0,
#    'success': True,
#    'mask_frac': 0.3125,
#    'fluency': 4.387331798284078,
#    'sem_similarity': 0.7120944261550903,
#    'minimality': 0.5,
#    'fluency_mice': 1.2076940579808808}],
#  'results_best': {'original_text': '. . . what the fuck did he do this time?',
#   'mask_frac': 0.3125,
#   'original_label': 1,
#   'original_pred_proba': 0.8979050517082211,
#   'counterfactual_label_name': 'not offensive',
#   'success': True,
#   'results': [{'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#     'edited_output_text': 'not offensive :... what in hell do he do this time?',
#     'pred_proba': 0.7348201870918274,
#     'pred_class': 1,
#     'success': False,
#     'mask_frac': 0.3125},
#    {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#     'edited_output_text': 'not offensive :... what the hell did he do this time?',
#     'pred_proba': 0.8040695190429688,
#     'pred_class': 1,
#     'success': False,
#     'mask_frac': 0.3125},
#    {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#     'edited_output_text': 'not offensive :... what other thing could he do this time?',
#     'pred_proba': 0.2108921855688095,
#     'pred_class': 0,
#     'success': True,
#     'mask_frac': 0.3125},
#    {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#     'edited_output_text': 'not offensive :... what of that did he do this time?',
#     'pred_proba': 0.21467173099517822,
#     'pred_class': 0,
#     'success': True,
#     'mask_frac': 0.3125},
#    {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#     'edited_output_text': 'not offensive :... what the fuck did he do this time?',
#     'pred_proba': 0.8662623167037964,
#     'pred_class': 1,
#     'success': False,
#     'mask_frac': 0.3125},
#    {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#     'edited_output_text': 'not offensive :... what the hell can he do this time?',
#     'pred_proba': 0.7990290522575378,
#     'pred_class': 1,
#     'success': False,
#     'mask_frac': 0.3125},
#    {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#     'edited_output_text': 'not offensive :... what the fuck can he do this time?',
#     'pred_proba': 0.8672462701797485,
#     'pred_class': 1,
#     'success': False,
#     'mask_frac': 0.3125},
#    {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#     'edited_output_text': 'not offensive :... what the hell should he do this time?',
#     'pred_proba': 0.7986152172088623,
#     'pred_class': 1,
#     'success': False,
#     'mask_frac': 0.3125},
#    {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#     'edited_output_text': 'not offensive :... what the fuck does he do this time?',
#     'pred_proba': 0.871511697769165,
#     'pred_class': 1,
#     'success': False,
#     'mask_frac': 0.3125},
#    {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#     'edited_output_text': 'not offensive :... what the hell does he do this time?',
#     'pred_proba': 0.8092130422592163,
#     'pred_class': 1,
#     'success': False,
#     'mask_frac': 0.3125}]},
#  'results_search_hist': [{'original_text': '. . . what the fuck did he do this time?',
#    'mask_frac': 0.25,
#    'original_label': 1,
#    'original_pred_proba': 0.8979050517082211,
#    'counterfactual_label_name': 'not offensive',
#    'success': False,
#    'results': [{'masked_text': '[CLS] not offensive :... what [MASK] [MASK] did he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the hell did he do this time?',
#      'pred_proba': 0.8040695190429688,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.25},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] did he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the fuck did he do this time?',
#      'pred_proba': 0.8662623167037964,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.25}]},
#   {'original_text': '. . . what the fuck did he do this time?',
#    'mask_frac': 0.375,
#    'original_label': 1,
#    'original_pred_proba': 0.8979050517082211,
#    'counterfactual_label_name': 'not offensive',
#    'success': True,
#    'results': [{'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the hell did he do this time?',
#      'pred_proba': 0.8040695190429688,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.375},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what of course could he do this time?',
#      'pred_proba': 0.1763102412223816,
#      'pred_class': 0,
#      'success': True,
#      'mask_frac': 0.375},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the heck did he do this time?',
#      'pred_proba': 0.7464421987533569,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.375},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the hell does he do this time?',
#      'pred_proba': 0.8092130422592163,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.375},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the hell can he do this time?',
#      'pred_proba': 0.7990290522575378,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.375},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the hell would he do this time?',
#      'pred_proba': 0.7788304090499878,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.375},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what other thing could he do this time?',
#      'pred_proba': 0.2108921855688095,
#      'pred_class': 0,
#      'success': True,
#      'mask_frac': 0.375},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the heck does he do this time?',
#      'pred_proba': 0.7471333146095276,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.375},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the fuck can he do this time?',
#      'pred_proba': 0.8672462701797485,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.375},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what a deal does he do this time?',
#      'pred_proba': 0.18134333193302155,
#      'pred_class': 0,
#      'success': True,
#      'mask_frac': 0.375},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what is it did he do this time?',
#      'pred_proba': 0.22401383519172668,
#      'pred_class': 0,
#      'success': True,
#      'mask_frac': 0.375}]},
#   {'original_text': '. . . what the fuck did he do this time?',
#    'mask_frac': 0.3125,
#    'original_label': 1,
#    'original_pred_proba': 0.8979050517082211,
#    'counterfactual_label_name': 'not offensive',
#    'success': True,
#    'results': [{'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what in hell do he do this time?',
#      'pred_proba': 0.7348201870918274,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.3125},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the hell did he do this time?',
#      'pred_proba': 0.8040695190429688,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.3125},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what other thing could he do this time?',
#      'pred_proba': 0.2108921855688095,
#      'pred_class': 0,
#      'success': True,
#      'mask_frac': 0.3125},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what of that did he do this time?',
#      'pred_proba': 0.21467173099517822,
#      'pred_class': 0,
#      'success': True,
#      'mask_frac': 0.3125},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the fuck did he do this time?',
#      'pred_proba': 0.8662623167037964,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.3125},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the hell can he do this time?',
#      'pred_proba': 0.7990290522575378,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.3125},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the fuck can he do this time?',
#      'pred_proba': 0.8672462701797485,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.3125},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the hell should he do this time?',
#      'pred_proba': 0.7986152172088623,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.3125},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the fuck does he do this time?',
#      'pred_proba': 0.871511697769165,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.3125},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the hell does he do this time?',
#      'pred_proba': 0.8092130422592163,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.3125}]},
#   {'original_text': '. . . what the fuck did he do this time?',
#    'mask_frac': 0.28125,
#    'original_label': 1,
#    'original_pred_proba': 0.8979050517082211,
#    'counterfactual_label_name': 'not offensive',
#    'success': False,
#    'results': [{'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the fuck can he do this time?',
#      'pred_proba': 0.8672462701797485,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.28125},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the hell could he do this time?',
#      'pred_proba': 0.7849062085151672,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.28125},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the hell does he do this time?',
#      'pred_proba': 0.8092130422592163,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.28125},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the fuck would he do this time?',
#      'pred_proba': 0.8536167740821838,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.28125},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what in hell would he do this time?',
#      'pred_proba': 0.7008148431777954,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.28125},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the hell do he do this time?',
#      'pred_proba': 0.7980067133903503,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.28125},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the fuck does he do this time?',
#      'pred_proba': 0.871511697769165,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.28125},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the hell did he do this time?',
#      'pred_proba': 0.8040695190429688,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.28125},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the hell can he do this time?',
#      'pred_proba': 0.7990290522575378,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.28125},
#     {'masked_text': '[CLS] not offensive :... what [MASK] [MASK] [MASK] he do this time? [SEP]',
#      'edited_output_text': 'not offensive :... what the heck does he do this time?',
#      'pred_proba': 0.7471333146095276,
#      'pred_class': 1,
#      'success': False,
#      'mask_frac': 0.28125}]}],
#  'time_generation': 0.38850903511047363,
#  'time_evaluation': 0.28434205055236816,
#  'error': None}

# %%
lines
# Out:
# []
